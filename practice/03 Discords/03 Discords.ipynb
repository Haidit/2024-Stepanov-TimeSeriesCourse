# %% [markdown]
# ## Анализ и прогнозирование временных рядов методами искусственного интеллекта

# %% [markdown]
# ### **Практическая работа 3. Поиск аномалий во временных рядах.**

# %% [markdown]
# #### **3.1 Поиск диссонансов с помощью алгоритма HotSAX**

# %% [markdown]
# ##### 3.1.1 Загрузка и подготовка данных

# %% [markdown]
# В данной будет использоваться временной ряд, состоящий из показаний акселерометра.
# Анализируемый временной ряд, описывает две активности человека - бег и шаг.

# %%
# %pip install scipy
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scipy in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (1.14.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (from scipy) (1.26.2)
# Requirement already satisfied: scikit-learn in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from time import time
import pandas as pd

# %%
#fixme: Путь
dataset_dir_path = Path('C:/2024-Stepanov-TimeSeriesCourse/practice/03 Discords/datasets')
data_path = dataset_dir_path/'walk_run.txt'
walk_run = np.loadtxt(data_path)[3000:4000]
data = walk_run
size_sub = 50

# %% [markdown]
# В середине временного ряда происходит смена активности (бег заменяет шаг). Нетипичным поведением, которое мы могли бы назвать диссонансами в данном ряде выступает небольшой участок между активностями, когда человек плавно увеличивает скорость шага до бега. В ходе данной работе наша задача выделить с помощью различных алгоритмов границы нашего диссонанса.

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(data[:],label='Шаг')
plt.plot(np.arange(data.shape[0]//2,data.shape[0]),data[data.shape[0]//2:],label='Бег')
plt.legend()

# %%
result={}
times={}

# %% [markdown]
# ##### 3.1.2 Реализация полного перебора

# %% [markdown]
# Приводится пример кода для нахождения топ 5 диссонансов с помощью реализации полного беребора.
# Вам необходимо добавить код для сбора времени обработки данных.

# %%
from modules.saxpy.discord import find_discords_brute_force
start = time()
discords_brute_force= np.stack(find_discords_brute_force(data[:], 50, 5))
end = time()
result['brute_force'] = discords_brute_force
times['brute_force'] = end-start

# %% [markdown]
# ##### 3.1.3 HotSAX

# %% [markdown]
# Используя [реализацию](https://github.com/seninp/saxpy/blob/master/saxpy/hotsax.py) найдите топ 5 диссонансов ряда.
# Произведите замер времени работы.

# %%
from modules.saxpy.hotsax import find_discords_hotsax
start = time()
discords_brute_force= np.stack(find_discords_hotsax(data[:], 50, 5))
end = time()

result['hotsax'] = discords_brute_force
times['hotsax'] = end-start

# %%
print(result)
print(times)
# Out:
# {'hotsax': array([[477.        ,   5.88100934],
#        [412.        ,   5.32704317],
#        [195.        ,   3.39426635],
#        [577.        ,   3.35554403],
#        [278.        ,   3.10959389]]), 'brute_force': array([[477.        ,   5.88100934],
#        [412.        ,   5.32704317],
#        [195.        ,   3.39426635],
#        [577.        ,   3.35554403],
#        [278.        ,   3.10959389]])}
# {'hotsax': 1.1923654079437256, 'brute_force': 61.348166942596436}

# %% [markdown]
# ##### 3.1.4 Визаулизация

# %% [markdown]
# Вам необходимо реализовать код позволяющий:
# 1. Вывести на одном графике ряд и его диссонансы
# 2. Столбчатую диаграмму времени работы обоих алгоритмов
#
# Постройте графики для обоих алгоритмов и сравните полученные результаты.
#
# Пример графика:
#
# ![first_graf](pics/fig_ex_1.png)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8))
fig, (ax3) = plt.subplots(1, figsize=(14, 8))
ax1.label = 'brute force'
ax2.label = 'hotsax'
ax3.label = 'times'
mn, mx = min(data), max(data)

for i in range(len(result['brute_force'])):
    alpha = 1 - (i + 3)*0.1
    ax1.add_patch(Rectangle(xy=(result['brute_force'][i][0], mn), width=size_sub, height=mx-mn, color='blue', alpha=alpha))
    ax1.text(result['brute_force'][i][0]+size_sub / 2, mx, f"#{i+1}", ha='center')
ax1.plot(data[:], label='Шаг')
ax1.plot(np.arange(data.shape[0] // 2, data.shape[0]), data[data.shape[0] // 2:], label='Бег')
    
for i in range(len(result['hotsax'])):
    alpha = 1-(i+3)*0.1
    ax2.add_patch(Rectangle(xy=(result['hotsax'][i][0], mn), width=size_sub, height=mx-mn, color='red', alpha=alpha))
    ax2.text(result['hotsax'][i][0]+size_sub/2, mx, f"#{i+1}", ha='center')
ax2.plot(data[:], label='Шаг')
ax2.plot(np.arange(data.shape[0]//2, data.shape[0]), data[data.shape[0]//2:], label='Бег')

ax3.bar(['brute force', 'hotsax'], [times['brute_force'], times['hotsax']], color=['blue', 'red'], alpha=0.5)
ax3.set_ylabel('Время, с.')
# Out:
# Text(0, 0.5, 'Время, с.')

# %%
from matplotlib.patches import Rectangle

# %% [markdown]
# ##### 3.1.5 Такси NY
#
# Произведите поиск диссонансов с помощью обоих алгоритмов на наборе данных, содержащим информацию о среднем числе пассажиров в NY. Отобразите найденные диссонансы обоими алгоритмами.

# %%
nyc_taxi = pd.read_csv(dataset_dir_path/'nyc_taxi.csv',index_col=0).values[4000:8000,0].astype(np.float64)
fig = plt.figure(figsize=(18, 4))
plt.plot(nyc_taxi)

# %%
brute_force = find_discords_brute_force(nyc_taxi[:], win_size=size_sub, num_discords=1)

# %%
hotsax = find_discords_hotsax(nyc_taxi[:], num_discords=5, win_size=size_sub)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8))
ax1.set_title('brute force')
ax2.set_title('hotsax')
mn, mx = min(nyc_taxi), max(nyc_taxi)

for i in range(len(brute_force)):
    alpha = 0.3
    ax1.add_patch(Rectangle(xy=(brute_force[i][0], mn), width=size_sub, height=mx-mn, color='red', alpha=alpha))
    ax1.text(brute_force[i][0]+size_sub/2, mx, f"#{i+1}", ha='center')
ax1.plot(nyc_taxi)
    
for i in range(len(hotsax)):
    alpha = 0.3
    ax2.add_patch(Rectangle(xy=(hotsax[i][0], mn), width=size_sub, height=mx-mn, color='red', alpha=alpha))
    ax2.text(hotsax[i][0]+size_sub/2, mx, f"#{i+1}", ha='center')
ax2.plot(nyc_taxi)

# %% [markdown]
# #### **3.2 Поиск диссонансов с помощью алгоритма DRAG**

# %%
# %pip install stumpy==1.11.1
# Out:
# Collecting stumpy==1.11.1Note: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for stumpy==1.11.1 from https://files.pythonhosted.org/packages/df/1b/85e852954e0453a7bc3bf45521b3f523bd5832d17e8efea09c8cf7c2cca5/stumpy-1.11.1-py3-none-any.whl.metadata
#   Downloading stumpy-1.11.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (from stumpy==1.11.1) (1.26.2)
# Requirement already satisfied: scipy>=1.5 in c:\users\stepx\appdata\local\programs\python\python312\lib\site-packages (from stumpy==1.11.1) (1.14.1)
# Collecting numba>=0.54 (from stumpy==1.11.1)
#   Obtaining dependency information for numba>=0.54 from https://files.pythonhosted.org/packages/ca/bd/0fe29fcd1b6a8de479a4ed25c6e56470e467e3611c079d55869ceef2b6d1/numba-0.60.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading numba-0.60.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.54->stumpy==1.11.1)
#   Obtaining dependency information for llvmlite<0.44,>=0.43.0dev0 from https://files.pythonhosted.org/packages/c6/94/dea10e263655ce78d777e78d904903faae39d1fc440762be4a9dc46bed49/llvmlite-0.43.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading llvmlite-0.43.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Downloading stumpy-1.11.1-py3-none-any.whl (136 kB)
#    ---------------------------------------- 0.0/136.2 kB ? eta -:--:--
#    --------------- ------------------------ 51.2/136.2 kB 1.3 MB/s eta 0:00:01
#    ----------------- --------------------- 61.4/136.2 kB 825.8 kB/s eta 0:00:01
#    ---------------------------- --------- 102.4/136.2 kB 991.0 kB/s eta 0:00:01
#    -------------------------------------- 136.2/136.2 kB 807.2 kB/s eta 0:00:00
# Downloading numba-0.60.0-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.7 MB 991.0 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/2.7 MB 1.1 MB/s eta 0:00:03
#    - -------------------------------------- 0.1/2.7 MB 1.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.2/2.7 MB 1.1 MB/s eta 0:00:03
#    --- ------------------------------------ 0.2/2.7 MB 1.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.2/2.7 MB 1.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.7 MB 999.9 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.4/2.7 MB 969.8 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.4/2.7 MB 955.7 kB/s eta 0:00:03
#    ------ --------------------------------- 0.4/2.7 MB 984.2 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 942.1 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 942.1 kB/s eta 0:00:03
#    -------- ------------------------------- 0.6/2.7 MB 915.2 kB/s eta 0:00:03
#    -------- ------------------------------- 0.6/2.7 MB 915.2 kB/s eta 0:00:03
#    --------- ------------------------------ 0.6/2.7 MB 921.0 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.7/2.7 MB 941.3 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.7/2.7 MB 917.8 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.7/2.7 MB 925.1 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.7 MB 912.8 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.7 MB 910.7 kB/s eta 0:00:03
#    ------------- -------------------------- 0.9/2.7 MB 928.9 kB/s eta 0:00:02
#    ------------- -------------------------- 0.9/2.7 MB 921.6 kB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.7 MB 896.7 kB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.7 MB 899.4 kB/s eta 0:00:02
#    --------------- ------------------------ 1.1/2.7 MB 903.5 kB/s eta 0:00:02
#    --------------- ------------------------ 1.1/2.7 MB 885.3 kB/s eta 0:00:02
#    ---------------- ----------------------- 1.1/2.7 MB 904.5 kB/s eta 0:00:02
#    ----------------- ---------------------- 1.2/2.7 MB 897.6 kB/s eta 0:00:02
#    ----------------- ---------------------- 1.2/2.7 MB 897.6 kB/s eta 0:00:02
#    ----------------- ---------------------- 1.2/2.7 MB 871.3 kB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.7 MB 897.9 kB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.7 MB 883.2 kB/s eta 0:00:02
#    -------------------- ------------------- 1.4/2.7 MB 907.9 kB/s eta 0:00:02
#    --------------------- ------------------ 1.4/2.7 MB 902.0 kB/s eta 0:00:02
#    --------------------- ------------------ 1.5/2.7 MB 888.5 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.5/2.7 MB 902.8 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.5/2.7 MB 894.1 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 897.6 kB/s eta 0:00:02
#    ------------------------ --------------- 1.6/2.7 MB 900.3 kB/s eta 0:00:02
#    ------------------------ --------------- 1.7/2.7 MB 890.2 kB/s eta 0:00:02
#    ------------------------- -------------- 1.7/2.7 MB 901.1 kB/s eta 0:00:02
#    ------------------------- -------------- 1.8/2.7 MB 898.7 kB/s eta 0:00:02
#    -------------------------- ------------- 1.8/2.7 MB 890.9 kB/s eta 0:00:02
#    -------------------------- ------------- 1.8/2.7 MB 894.4 kB/s eta 0:00:02
#    --------------------------- ------------ 1.9/2.7 MB 896.9 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.7 MB 894.8 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.7 MB 897.7 kB/s eta 0:00:01
#    ----------------------------- ---------- 2.0/2.7 MB 893.8 kB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 897.9 kB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 896.1 kB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 896.8 kB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.7 MB 892.1 kB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.7 MB 899.2 kB/s eta 0:00:01
#    --------------------------------- ------ 2.3/2.7 MB 891.7 kB/s eta 0:00:01
#    --------------------------------- ------ 2.3/2.7 MB 887.3 kB/s eta 0:00:01
#    --------------------------------- ------ 2.3/2.7 MB 887.3 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 894.5 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 890.3 kB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.7 MB 896.7 kB/s eta 0:00:01
#    ------------------------------------- -- 2.5/2.7 MB 897.0 kB/s eta 0:00:01
#    ------------------------------------- -- 2.5/2.7 MB 886.0 kB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 894.0 kB/s eta 0:00:01
#    ---------------------------------------  2.6/2.7 MB 896.0 kB/s eta 0:00:01
#    ---------------------------------------  2.6/2.7 MB 896.0 kB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 888.5 kB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 885.2 kB/s eta 0:00:00
# Downloading llvmlite-0.43.0-cp312-cp312-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/28.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/28.1 MB 1.2 MB/s eta 0:00:24
#    ---------------------------------------- 0.1/28.1 MB 1.2 MB/s eta 0:00:24
#    ---------------------------------------- 0.2/28.1 MB 1.2 MB/s eta 0:00:25
#    ---------------------------------------- 0.2/28.1 MB 1.0 MB/s eta 0:00:28
#    ---------------------------------------- 0.2/28.1 MB 1.0 MB/s eta 0:00:28
#    ---------------------------------------- 0.3/28.1 MB 999.9 kB/s eta 0:00:28
#     --------------------------------------- 0.4/28.1 MB 967.1 kB/s eta 0:00:29
#     --------------------------------------- 0.4/28.1 MB 995.6 kB/s eta 0:00:28
#     --------------------------------------- 0.4/28.1 MB 904.2 kB/s eta 0:00:31
#     --------------------------------------- 0.4/28.1 MB 895.2 kB/s eta 0:00:31
#     --------------------------------------- 0.5/28.1 MB 952.6 kB/s eta 0:00:29
#     --------------------------------------- 0.6/28.1 MB 956.7 kB/s eta 0:00:29
#     --------------------------------------- 0.6/28.1 MB 894.6 kB/s eta 0:00:31
#     --------------------------------------- 0.6/28.1 MB 929.5 kB/s eta 0:00:30
#     --------------------------------------- 0.7/28.1 MB 925.7 kB/s eta 0:00:30
#    - -------------------------------------- 0.7/28.1 MB 903.5 kB/s eta 0:00:31
#    - -------------------------------------- 0.7/28.1 MB 925.1 kB/s eta 0:00:30
#    - -------------------------------------- 0.8/28.1 MB 928.7 kB/s eta 0:00:30
#    - -------------------------------------- 0.8/28.1 MB 888.5 kB/s eta 0:00:31
#    - -------------------------------------- 0.9/28.1 MB 927.9 kB/s eta 0:00:30
#    - -------------------------------------- 0.9/28.1 MB 917.2 kB/s eta 0:00:30
#    - -------------------------------------- 0.9/28.1 MB 917.2 kB/s eta 0:00:30
#    - -------------------------------------- 1.0/28.1 MB 921.4 kB/s eta 0:00:30
#    - -------------------------------------- 1.0/28.1 MB 906.4 kB/s eta 0:00:30
#    - -------------------------------------- 1.1/28.1 MB 908.7 kB/s eta 0:00:30
#    - -------------------------------------- 1.1/28.1 MB 915.6 kB/s eta 0:00:30
#    - -------------------------------------- 1.2/28.1 MB 907.9 kB/s eta 0:00:30
#    - -------------------------------------- 1.2/28.1 MB 907.9 kB/s eta 0:00:30
#    - -------------------------------------- 1.3/28.1 MB 918.6 kB/s eta 0:00:30
#    - -------------------------------------- 1.3/28.1 MB 885.7 kB/s eta 0:00:31
#    - -------------------------------------- 1.3/28.1 MB 902.1 kB/s eta 0:00:30
#    - -------------------------------------- 1.4/28.1 MB 905.1 kB/s eta 0:00:30
#    -- ------------------------------------- 1.4/28.1 MB 908.5 kB/s eta 0:00:30
#    -- ------------------------------------- 1.5/28.1 MB 915.0 kB/s eta 0:00:30
#    -- ------------------------------------- 1.5/28.1 MB 908.4 kB/s eta 0:00:30
#    -- ------------------------------------- 1.6/28.1 MB 905.5 kB/s eta 0:00:30
#    -- ------------------------------------- 1.6/28.1 MB 908.9 kB/s eta 0:00:30
#    -- ------------------------------------- 1.6/28.1 MB 900.3 kB/s eta 0:00:30
#    -- ------------------------------------- 1.7/28.1 MB 897.4 kB/s eta 0:00:30
#    -- ------------------------------------- 1.7/28.1 MB 901.1 kB/s eta 0:00:30
#    -- ------------------------------------- 1.8/28.1 MB 896.6 kB/s eta 0:00:30
#    -- ------------------------------------- 1.8/28.1 MB 901.1 kB/s eta 0:00:30
#    -- ------------------------------------- 1.8/28.1 MB 890.4 kB/s eta 0:00:30
#    -- ------------------------------------- 1.9/28.1 MB 899.8 kB/s eta 0:00:30
#    -- ------------------------------------- 1.9/28.1 MB 894.4 kB/s eta 0:00:30
#    -- ------------------------------------- 2.0/28.1 MB 895.8 kB/s eta 0:00:30
#    -- ------------------------------------- 2.0/28.1 MB 893.4 kB/s eta 0:00:30
#    -- ------------------------------------- 2.1/28.1 MB 891.6 kB/s eta 0:00:30
#    -- ------------------------------------- 2.1/28.1 MB 888.5 kB/s eta 0:00:30
#    --- ------------------------------------ 2.1/28.1 MB 896.8 kB/s eta 0:00:29
#    --- ------------------------------------ 2.2/28.1 MB 892.1 kB/s eta 0:00:30
#    --- ------------------------------------ 2.2/28.1 MB 893.3 kB/s eta 0:00:29
#    --- ------------------------------------ 2.3/28.1 MB 899.5 kB/s eta 0:00:29
#    --- ------------------------------------ 2.3/28.1 MB 887.0 kB/s eta 0:00:30
#    --- ------------------------------------ 2.3/28.1 MB 896.1 kB/s eta 0:00:29
#    --- ------------------------------------ 2.4/28.1 MB 894.1 kB/s eta 0:00:29
#    --- ------------------------------------ 2.4/28.1 MB 896.8 kB/s eta 0:00:29
#    --- ------------------------------------ 2.4/28.1 MB 891.1 kB/s eta 0:00:29
#    --- ------------------------------------ 2.5/28.1 MB 889.6 kB/s eta 0:00:29
#    --- ------------------------------------ 2.5/28.1 MB 880.8 kB/s eta 0:00:30
#    --- ------------------------------------ 2.6/28.1 MB 894.0 kB/s eta 0:00:29
#    --- ------------------------------------ 2.6/28.1 MB 891.2 kB/s eta 0:00:29
#    --- ------------------------------------ 2.6/28.1 MB 891.2 kB/s eta 0:00:29
#    --- ------------------------------------ 2.7/28.1 MB 896.3 kB/s eta 0:00:29
#    --- ------------------------------------ 2.8/28.1 MB 894.9 kB/s eta 0:00:29
#    --- ------------------------------------ 2.8/28.1 MB 893.6 kB/s eta 0:00:29
#    ---- ----------------------------------- 2.8/28.1 MB 884.5 kB/s eta 0:00:29
#    ---- ----------------------------------- 2.9/28.1 MB 890.7 kB/s eta 0:00:29
#    ---- ----------------------------------- 2.9/28.1 MB 889.5 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.0/28.1 MB 894.5 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.0/28.1 MB 893.0 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.0/28.1 MB 892.0 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.1/28.1 MB 888.5 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.1/28.1 MB 888.3 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.2/28.1 MB 894.1 kB/s eta 0:00:28
#    ---- ----------------------------------- 3.2/28.1 MB 887.8 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.3/28.1 MB 891.5 kB/s eta 0:00:28
#    ---- ----------------------------------- 3.3/28.1 MB 890.4 kB/s eta 0:00:28
#    ---- ----------------------------------- 3.3/28.1 MB 891.0 kB/s eta 0:00:28
#    ---- ----------------------------------- 3.4/28.1 MB 887.3 kB/s eta 0:00:28
#    ---- ----------------------------------- 3.4/28.1 MB 892.7 kB/s eta 0:00:28
#    ---- ----------------------------------- 3.5/28.1 MB 890.5 kB/s eta 0:00:28
#    ---- ----------------------------------- 3.5/28.1 MB 887.7 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.5/28.1 MB 891.1 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.6/28.1 MB 888.9 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.6/28.1 MB 886.4 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.6/28.1 MB 891.4 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.7/28.1 MB 889.3 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.8/28.1 MB 888.3 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.8/28.1 MB 889.8 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.8/28.1 MB 891.3 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.9/28.1 MB 890.1 kB/s eta 0:00:28
#    ----- ---------------------------------- 3.9/28.1 MB 886.2 kB/s eta 0:00:28
#    ----- ---------------------------------- 4.0/28.1 MB 889.9 kB/s eta 0:00:28
#    ----- ---------------------------------- 4.0/28.1 MB 889.9 kB/s eta 0:00:28
#    ----- ---------------------------------- 4.0/28.1 MB 888.9 kB/s eta 0:00:28
#    ----- ---------------------------------- 4.1/28.1 MB 890.2 kB/s eta 0:00:27
#    ----- ---------------------------------- 4.1/28.1 MB 889.2 kB/s eta 0:00:27
#    ----- ---------------------------------- 4.2/28.1 MB 890.5 kB/s eta 0:00:27
#    ------ --------------------------------- 4.2/28.1 MB 888.8 kB/s eta 0:00:27
#    ------ --------------------------------- 4.3/28.1 MB 890.8 kB/s eta 0:00:27
#    ------ --------------------------------- 4.3/28.1 MB 890.2 kB/s eta 0:00:27
#    ------ --------------------------------- 4.3/28.1 MB 887.0 kB/s eta 0:00:27
#    ------ --------------------------------- 4.4/28.1 MB 890.4 kB/s eta 0:00:27
#    ------ --------------------------------- 4.4/28.1 MB 886.9 kB/s eta 0:00:27
#    ------ --------------------------------- 4.5/28.1 MB 888.8 kB/s eta 0:00:27
#    ------ --------------------------------- 4.5/28.1 MB 887.9 kB/s eta 0:00:27
#    ------ --------------------------------- 4.5/28.1 MB 888.5 kB/s eta 0:00:27
#    ------ --------------------------------- 4.6/28.1 MB 887.6 kB/s eta 0:00:27
#    ------ --------------------------------- 4.6/28.1 MB 885.6 kB/s eta 0:00:27
#    ------ --------------------------------- 4.6/28.1 MB 885.6 kB/s eta 0:00:27
#    ------ --------------------------------- 4.7/28.1 MB 889.3 kB/s eta 0:00:27
#    ------ --------------------------------- 4.8/28.1 MB 884.5 kB/s eta 0:00:27
#    ------ --------------------------------- 4.8/28.1 MB 885.1 kB/s eta 0:00:27
#    ------ --------------------------------- 4.8/28.1 MB 885.8 kB/s eta 0:00:27
#    ------ --------------------------------- 4.9/28.1 MB 886.2 kB/s eta 0:00:27
#    ------ --------------------------------- 4.9/28.1 MB 889.2 kB/s eta 0:00:27
#    ------- -------------------------------- 5.0/28.1 MB 888.5 kB/s eta 0:00:27
#    ------- -------------------------------- 5.0/28.1 MB 884.0 kB/s eta 0:00:27
#    ------- -------------------------------- 5.0/28.1 MB 887.0 kB/s eta 0:00:27
#    ------- -------------------------------- 5.1/28.1 MB 887.4 kB/s eta 0:00:26
#    ------- -------------------------------- 5.1/28.1 MB 887.4 kB/s eta 0:00:26
#    ------- -------------------------------- 5.2/28.1 MB 888.5 kB/s eta 0:00:26
#    ------- -------------------------------- 5.2/28.1 MB 887.7 kB/s eta 0:00:26
#    ------- -------------------------------- 5.2/28.1 MB 884.8 kB/s eta 0:00:26
#    ------- -------------------------------- 5.3/28.1 MB 886.4 kB/s eta 0:00:26
#    ------- -------------------------------- 5.3/28.1 MB 886.8 kB/s eta 0:00:26
#    ------- -------------------------------- 5.3/28.1 MB 886.8 kB/s eta 0:00:26
#    ------- -------------------------------- 5.4/28.1 MB 887.9 kB/s eta 0:00:26
#    ------- -------------------------------- 5.5/28.1 MB 887.1 kB/s eta 0:00:26
#    ------- -------------------------------- 5.5/28.1 MB 881.5 kB/s eta 0:00:26
#    ------- -------------------------------- 5.5/28.1 MB 886.9 kB/s eta 0:00:26
#    ------- -------------------------------- 5.6/28.1 MB 888.4 kB/s eta 0:00:26
#    ------- -------------------------------- 5.6/28.1 MB 883.5 kB/s eta 0:00:26
#    -------- ------------------------------- 5.7/28.1 MB 887.1 kB/s eta 0:00:26
#    -------- ------------------------------- 5.7/28.1 MB 885.9 kB/s eta 0:00:26
#    -------- ------------------------------- 5.7/28.1 MB 885.9 kB/s eta 0:00:26
#    -------- ------------------------------- 5.8/28.1 MB 886.3 kB/s eta 0:00:26
#    -------- ------------------------------- 5.8/28.1 MB 887.8 kB/s eta 0:00:26
#    -------- ------------------------------- 5.8/28.1 MB 887.3 kB/s eta 0:00:26
#    -------- ------------------------------- 5.9/28.1 MB 887.6 kB/s eta 0:00:25
#    -------- ------------------------------- 5.9/28.1 MB 886.1 kB/s eta 0:00:26
#    -------- ------------------------------- 6.0/28.1 MB 886.4 kB/s eta 0:00:25
#    -------- ------------------------------- 6.0/28.1 MB 885.3 kB/s eta 0:00:25
#    -------- ------------------------------- 6.1/28.1 MB 885.2 kB/s eta 0:00:25
#    -------- ------------------------------- 6.1/28.1 MB 886.7 kB/s eta 0:00:25
#    -------- ------------------------------- 6.2/28.1 MB 887.0 kB/s eta 0:00:25
#    -------- ------------------------------- 6.2/28.1 MB 882.5 kB/s eta 0:00:25
#    -------- ------------------------------- 6.2/28.1 MB 885.9 kB/s eta 0:00:25
#    -------- ------------------------------- 6.3/28.1 MB 886.8 kB/s eta 0:00:25
#    --------- ------------------------------ 6.3/28.1 MB 886.2 kB/s eta 0:00:25
#    --------- ------------------------------ 6.3/28.1 MB 885.6 kB/s eta 0:00:25
#    --------- ------------------------------ 6.4/28.1 MB 886.0 kB/s eta 0:00:25
#    --------- ------------------------------ 6.5/28.1 MB 884.5 kB/s eta 0:00:25
#    --------- ------------------------------ 6.5/28.1 MB 883.1 kB/s eta 0:00:25
#    --------- ------------------------------ 6.5/28.1 MB 886.3 kB/s eta 0:00:25
#    --------- ------------------------------ 6.6/28.1 MB 885.8 kB/s eta 0:00:25
#    --------- ------------------------------ 6.6/28.1 MB 885.2 kB/s eta 0:00:25
#    --------- ------------------------------ 6.7/28.1 MB 885.6 kB/s eta 0:00:25
#    --------- ------------------------------ 6.7/28.1 MB 884.1 kB/s eta 0:00:25
#    --------- ------------------------------ 6.7/28.1 MB 886.4 kB/s eta 0:00:25
#    --------- ------------------------------ 6.8/28.1 MB 885.8 kB/s eta 0:00:25
#    --------- ------------------------------ 6.8/28.1 MB 882.7 kB/s eta 0:00:25
#    --------- ------------------------------ 6.9/28.1 MB 885.7 kB/s eta 0:00:24
#    --------- ------------------------------ 6.9/28.1 MB 885.2 kB/s eta 0:00:24
#    --------- ------------------------------ 6.9/28.1 MB 886.5 kB/s eta 0:00:24
#    --------- ------------------------------ 7.0/28.1 MB 885.9 kB/s eta 0:00:24
#    --------- ------------------------------ 7.0/28.1 MB 885.4 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.0/28.1 MB 884.6 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.1/28.1 MB 885.3 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.2/28.1 MB 884.8 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.2/28.1 MB 882.6 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.2/28.1 MB 886.3 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.3/28.1 MB 885.8 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.3/28.1 MB 885.4 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.4/28.1 MB 886.1 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.4/28.1 MB 885.6 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.4/28.1 MB 885.2 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.5/28.1 MB 883.9 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.5/28.1 MB 885.5 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.6/28.1 MB 886.2 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.6/28.1 MB 881.0 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.7/28.1 MB 885.2 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.7/28.1 MB 886.4 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.7/28.1 MB 883.6 kB/s eta 0:00:24
#    ----------- ---------------------------- 7.8/28.1 MB 885.0 kB/s eta 0:00:23
#    ----------- ---------------------------- 7.8/28.1 MB 885.0 kB/s eta 0:00:23
#    ----------- ---------------------------- 7.9/28.1 MB 885.3 kB/s eta 0:00:23
#    ----------- ---------------------------- 7.9/28.1 MB 884.9 kB/s eta 0:00:23
#    ----------- ---------------------------- 7.9/28.1 MB 885.3 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.0/28.1 MB 884.8 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.0/28.1 MB 883.6 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.0/28.1 MB 885.5 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.1/28.1 MB 885.0 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.2/28.1 MB 884.6 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.2/28.1 MB 884.8 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.2/28.1 MB 884.8 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.2/28.1 MB 882.6 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.3/28.1 MB 885.1 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.4/28.1 MB 885.8 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.4/28.1 MB 885.8 kB/s eta 0:00:23
#    ----------- ---------------------------- 8.4/28.1 MB 884.5 kB/s eta 0:00:23
#    ------------ --------------------------- 8.5/28.1 MB 884.2 kB/s eta 0:00:23
#    ------------ --------------------------- 8.5/28.1 MB 883.8 kB/s eta 0:00:23
#    ------------ --------------------------- 8.6/28.1 MB 885.4 kB/s eta 0:00:23
#    ------------ --------------------------- 8.6/28.1 MB 884.0 kB/s eta 0:00:23
#    ------------ --------------------------- 8.6/28.1 MB 884.6 kB/s eta 0:00:23
#    ------------ --------------------------- 8.7/28.1 MB 885.6 kB/s eta 0:00:22
#    ------------ --------------------------- 8.7/28.1 MB 884.8 kB/s eta 0:00:22
#    ------------ --------------------------- 8.7/28.1 MB 884.8 kB/s eta 0:00:22
#    ------------ --------------------------- 8.8/28.1 MB 886.5 kB/s eta 0:00:22
#    ------------ --------------------------- 8.8/28.1 MB 882.0 kB/s eta 0:00:22
#    ------------ --------------------------- 8.9/28.1 MB 884.3 kB/s eta 0:00:22
#    ------------ --------------------------- 8.9/28.1 MB 883.6 kB/s eta 0:00:22
#    ------------ --------------------------- 9.0/28.1 MB 884.6 kB/s eta 0:00:22
#    ------------ --------------------------- 9.0/28.1 MB 883.9 kB/s eta 0:00:22
#    ------------ --------------------------- 9.1/28.1 MB 884.8 kB/s eta 0:00:22
#    ------------ --------------------------- 9.1/28.1 MB 883.4 kB/s eta 0:00:22
#    ------------ --------------------------- 9.1/28.1 MB 885.4 kB/s eta 0:00:22
#    ------------- -------------------------- 9.2/28.1 MB 884.3 kB/s eta 0:00:22
#    ------------- -------------------------- 9.2/28.1 MB 883.3 kB/s eta 0:00:22
#    ------------- -------------------------- 9.2/28.1 MB 885.3 kB/s eta 0:00:22
#    ------------- -------------------------- 9.3/28.1 MB 883.2 kB/s eta 0:00:22
#    ------------- -------------------------- 9.3/28.1 MB 883.2 kB/s eta 0:00:22
#    ------------- -------------------------- 9.4/28.1 MB 884.8 kB/s eta 0:00:22
#    ------------- -------------------------- 9.4/28.1 MB 884.4 kB/s eta 0:00:22
#    ------------- -------------------------- 9.5/28.1 MB 882.1 kB/s eta 0:00:22
#    ------------- -------------------------- 9.5/28.1 MB 884.3 kB/s eta 0:00:22
#    ------------- -------------------------- 9.5/28.1 MB 884.2 kB/s eta 0:00:21
#    ------------- -------------------------- 9.6/28.1 MB 881.0 kB/s eta 0:00:22
#    ------------- -------------------------- 9.6/28.1 MB 884.4 kB/s eta 0:00:21
#    ------------- -------------------------- 9.7/28.1 MB 885.1 kB/s eta 0:00:21
#    ------------- -------------------------- 9.7/28.1 MB 885.1 kB/s eta 0:00:21
#    ------------- -------------------------- 9.7/28.1 MB 885.3 kB/s eta 0:00:21
#    ------------- -------------------------- 9.8/28.1 MB 882.8 kB/s eta 0:00:21
#    ------------- -------------------------- 9.8/28.1 MB 883.3 kB/s eta 0:00:21
#    -------------- ------------------------- 9.9/28.1 MB 882.7 kB/s eta 0:00:21
#    -------------- ------------------------- 9.9/28.1 MB 883.5 kB/s eta 0:00:21
#    -------------- ------------------------- 9.9/28.1 MB 883.5 kB/s eta 0:00:21
#    -------------- ------------------------- 10.0/28.1 MB 884.9 kB/s eta 0:00:21
#    -------------- ------------------------- 10.1/28.1 MB 884.3 kB/s eta 0:00:21
#    -------------- ------------------------- 10.1/28.1 MB 884.3 kB/s eta 0:00:21
#    -------------- ------------------------- 10.1/28.1 MB 882.5 kB/s eta 0:00:21
#    -------------- ------------------------- 10.2/28.1 MB 883.3 kB/s eta 0:00:21
#    -------------- ------------------------- 10.2/28.1 MB 883.9 kB/s eta 0:00:21
#    -------------- ------------------------- 10.2/28.1 MB 883.6 kB/s eta 0:00:21
#    -------------- ------------------------- 10.3/28.1 MB 883.6 kB/s eta 0:00:21
#    -------------- ------------------------- 10.3/28.1 MB 883.6 kB/s eta 0:00:21
#    -------------- ------------------------- 10.4/28.1 MB 884.8 kB/s eta 0:00:21
#    -------------- ------------------------- 10.4/28.1 MB 883.5 kB/s eta 0:00:21
#    -------------- ------------------------- 10.4/28.1 MB 883.5 kB/s eta 0:00:21
#    -------------- ------------------------- 10.5/28.1 MB 882.4 kB/s eta 0:00:20
#    -------------- ------------------------- 10.5/28.1 MB 880.0 kB/s eta 0:00:20
#    --------------- ------------------------ 10.6/28.1 MB 882.4 kB/s eta 0:00:20
#    --------------- ------------------------ 10.6/28.1 MB 880.0 kB/s eta 0:00:20
#    --------------- ------------------------ 10.6/28.1 MB 882.3 kB/s eta 0:00:20
#    --------------- ------------------------ 10.7/28.1 MB 884.8 kB/s eta 0:00:20
#    --------------- ------------------------ 10.7/28.1 MB 884.7 kB/s eta 0:00:20
#    --------------- ------------------------ 10.8/28.1 MB 880.0 kB/s eta 0:00:20
#    --------------- ------------------------ 10.8/28.1 MB 883.6 kB/s eta 0:00:20
#    --------------- ------------------------ 10.9/28.1 MB 881.1 kB/s eta 0:00:20
#    --------------- ------------------------ 10.9/28.1 MB 881.2 kB/s eta 0:00:20
#    --------------- ------------------------ 10.9/28.1 MB 882.4 kB/s eta 0:00:20
#    --------------- ------------------------ 11.0/28.1 MB 884.8 kB/s eta 0:00:20
#    --------------- ------------------------ 11.0/28.1 MB 880.0 kB/s eta 0:00:20
#    --------------- ------------------------ 11.1/28.1 MB 882.3 kB/s eta 0:00:20
#    --------------- ------------------------ 11.1/28.1 MB 882.3 kB/s eta 0:00:20
#    --------------- ------------------------ 11.1/28.1 MB 883.6 kB/s eta 0:00:20
#    --------------- ------------------------ 11.2/28.1 MB 884.7 kB/s eta 0:00:20
#    --------------- ------------------------ 11.2/28.1 MB 878.8 kB/s eta 0:00:20
#    ---------------- ----------------------- 11.3/28.1 MB 882.3 kB/s eta 0:00:20
#    ---------------- ----------------------- 11.3/28.1 MB 881.1 kB/s eta 0:00:20
#    ---------------- ----------------------- 11.4/28.1 MB 883.6 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.4/28.1 MB 883.6 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.4/28.1 MB 884.8 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.5/28.1 MB 880.0 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.5/28.1 MB 882.3 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.6/28.1 MB 883.6 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.6/28.1 MB 880.0 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.6/28.1 MB 881.2 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.7/28.1 MB 882.3 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.7/28.1 MB 880.0 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.7/28.1 MB 878.8 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.8/28.1 MB 880.0 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.9/28.1 MB 880.0 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.9/28.1 MB 880.0 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.9/28.1 MB 882.3 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.9/28.1 MB 882.3 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.0/28.1 MB 883.6 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.1/28.1 MB 881.1 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.1/28.1 MB 881.2 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.1/28.1 MB 882.3 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.2/28.1 MB 881.1 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.2/28.1 MB 881.1 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.2/28.1 MB 883.6 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.3/28.1 MB 882.3 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.3/28.1 MB 880.0 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.4/28.1 MB 883.6 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.4/28.1 MB 881.1 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.5/28.1 MB 880.0 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.5/28.1 MB 881.2 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.6/28.1 MB 880.0 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.6/28.1 MB 880.0 kB/s eta 0:00:18
#    ----------------- ---------------------- 12.6/28.1 MB 881.1 kB/s eta 0:00:18
#    ------------------ --------------------- 12.7/28.1 MB 883.6 kB/s eta 0:00:18
#    ------------------ --------------------- 12.7/28.1 MB 880.0 kB/s eta 0:00:18
#    ------------------ --------------------- 12.8/28.1 MB 884.8 kB/s eta 0:00:18
#    ------------------ --------------------- 12.8/28.1 MB 880.0 kB/s eta 0:00:18
#    ------------------ --------------------- 12.8/28.1 MB 882.3 kB/s eta 0:00:18
#    ------------------ --------------------- 12.9/28.1 MB 882.3 kB/s eta 0:00:18
#    ------------------ --------------------- 12.9/28.1 MB 881.2 kB/s eta 0:00:18
#    ------------------ --------------------- 13.0/28.1 MB 880.0 kB/s eta 0:00:18
#    ------------------ --------------------- 13.0/28.1 MB 881.2 kB/s eta 0:00:18
#    ------------------ --------------------- 13.1/28.1 MB 883.5 kB/s eta 0:00:18
#    ------------------ --------------------- 13.1/28.1 MB 880.0 kB/s eta 0:00:18
#    ------------------ --------------------- 13.1/28.1 MB 883.6 kB/s eta 0:00:17
#    ------------------ --------------------- 13.2/28.1 MB 880.0 kB/s eta 0:00:17
#    ------------------ --------------------- 13.2/28.1 MB 880.0 kB/s eta 0:00:17
#    ------------------ --------------------- 13.3/28.1 MB 881.1 kB/s eta 0:00:17
#    ------------------ --------------------- 13.3/28.1 MB 882.3 kB/s eta 0:00:17
#    ------------------ --------------------- 13.3/28.1 MB 881.2 kB/s eta 0:00:17
#    ------------------- -------------------- 13.4/28.1 MB 880.0 kB/s eta 0:00:17
#    ------------------- -------------------- 13.4/28.1 MB 881.2 kB/s eta 0:00:17
#    ------------------- -------------------- 13.5/28.1 MB 880.0 kB/s eta 0:00:17
#    ------------------- -------------------- 13.5/28.1 MB 881.1 kB/s eta 0:00:17
#    ------------------- -------------------- 13.6/28.1 MB 881.2 kB/s eta 0:00:17
#    ------------------- -------------------- 13.6/28.1 MB 881.2 kB/s eta 0:00:17
#    ------------------- -------------------- 13.6/28.1 MB 878.8 kB/s eta 0:00:17
#    ------------------- -------------------- 13.7/28.1 MB 880.0 kB/s eta 0:00:17
#    ------------------- -------------------- 13.7/28.1 MB 881.1 kB/s eta 0:00:17
#    ------------------- -------------------- 13.8/28.1 MB 881.1 kB/s eta 0:00:17
#    ------------------- -------------------- 13.8/28.1 MB 881.2 kB/s eta 0:00:17
#    ------------------- -------------------- 13.8/28.1 MB 881.2 kB/s eta 0:00:17
#    ------------------- -------------------- 13.9/28.1 MB 883.6 kB/s eta 0:00:17
#    ------------------- -------------------- 13.9/28.1 MB 880.0 kB/s eta 0:00:17
#    ------------------- -------------------- 13.9/28.1 MB 883.5 kB/s eta 0:00:17
#    ------------------- -------------------- 14.0/28.1 MB 881.2 kB/s eta 0:00:17
#    -------------------- ------------------- 14.1/28.1 MB 878.8 kB/s eta 0:00:16
#    -------------------- ------------------- 14.1/28.1 MB 881.2 kB/s eta 0:00:16
#    -------------------- ------------------- 14.1/28.1 MB 882.3 kB/s eta 0:00:16
#    -------------------- ------------------- 14.2/28.1 MB 880.0 kB/s eta 0:00:16
#    -------------------- ------------------- 14.2/28.1 MB 880.0 kB/s eta 0:00:16
#    -------------------- ------------------- 14.3/28.1 MB 880.0 kB/s eta 0:00:16
#    -------------------- ------------------- 14.3/28.1 MB 880.0 kB/s eta 0:00:16
#    -------------------- ------------------- 14.3/28.1 MB 882.3 kB/s eta 0:00:16
#    -------------------- ------------------- 14.4/28.1 MB 880.0 kB/s eta 0:00:16
#    -------------------- ------------------- 14.4/28.1 MB 878.8 kB/s eta 0:00:16
#    -------------------- ------------------- 14.4/28.1 MB 881.2 kB/s eta 0:00:16
#    -------------------- ------------------- 14.5/28.1 MB 878.8 kB/s eta 0:00:16
#    -------------------- ------------------- 14.5/28.1 MB 878.8 kB/s eta 0:00:16
#    -------------------- ------------------- 14.6/28.1 MB 882.3 kB/s eta 0:00:16
#    -------------------- ------------------- 14.6/28.1 MB 880.0 kB/s eta 0:00:16
#    -------------------- ------------------- 14.6/28.1 MB 880.0 kB/s eta 0:00:16
#    -------------------- ------------------- 14.7/28.1 MB 881.2 kB/s eta 0:00:16
#    -------------------- ------------------- 14.7/28.1 MB 880.0 kB/s eta 0:00:16
#    -------------------- ------------------- 14.7/28.1 MB 880.0 kB/s eta 0:00:16
#    --------------------- ------------------ 14.8/28.1 MB 878.8 kB/s eta 0:00:16
#    --------------------- ------------------ 14.9/28.1 MB 882.3 kB/s eta 0:00:15
#    --------------------- ------------------ 14.9/28.1 MB 882.3 kB/s eta 0:00:15
#    --------------------- ------------------ 15.0/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.0/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.0/28.1 MB 881.2 kB/s eta 0:00:15
#    --------------------- ------------------ 15.1/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.1/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.1/28.1 MB 877.6 kB/s eta 0:00:15
#    --------------------- ------------------ 15.2/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.2/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.3/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.3/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.4/28.1 MB 881.1 kB/s eta 0:00:15
#    --------------------- ------------------ 15.4/28.1 MB 880.0 kB/s eta 0:00:15
#    --------------------- ------------------ 15.4/28.1 MB 878.8 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.5/28.1 MB 880.0 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.5/28.1 MB 878.8 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.6/28.1 MB 880.0 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.6/28.1 MB 880.0 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.6/28.1 MB 878.8 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.7/28.1 MB 878.8 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.7/28.1 MB 878.8 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.8/28.1 MB 880.0 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.8/28.1 MB 878.8 kB/s eta 0:00:14
#    ---------------------- ----------------- 15.8/28.1 MB 878.8 kB/s eta 0:00:14
#    ---------------------- ----------------- 15.9/28.1 MB 880.0 kB/s eta 0:00:14
#    ---------------------- ----------------- 15.9/28.1 MB 880.0 kB/s eta 0:00:14
#    ---------------------- ----------------- 16.0/28.1 MB 878.8 kB/s eta 0:00:14
#    ---------------------- ----------------- 16.0/28.1 MB 880.0 kB/s eta 0:00:14
#    ---------------------- ----------------- 16.1/28.1 MB 878.8 kB/s eta 0:00:14
#    ---------------------- ----------------- 16.1/28.1 MB 880.0 kB/s eta 0:00:14
#    ---------------------- ----------------- 16.1/28.1 MB 877.6 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.2/28.1 MB 881.2 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.2/28.1 MB 880.0 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.3/28.1 MB 880.0 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.3/28.1 MB 878.8 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.3/28.1 MB 878.8 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.4/28.1 MB 880.0 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.4/28.1 MB 880.0 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.5/28.1 MB 880.0 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.5/28.1 MB 878.8 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.6/28.1 MB 878.8 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.6/28.1 MB 878.8 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.6/28.1 MB 877.6 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.7/28.1 MB 880.0 kB/s eta 0:00:13
#    ----------------------- ---------------- 16.7/28.1 MB 880.0 kB/s eta 0:00:13
#    ----------------------- ---------------- 16.8/28.1 MB 878.8 kB/s eta 0:00:13
#    ----------------------- ---------------- 16.8/28.1 MB 878.8 kB/s eta 0:00:13
#    ----------------------- ---------------- 16.8/28.1 MB 878.8 kB/s eta 0:00:13
#    ------------------------ --------------- 16.9/28.1 MB 878.8 kB/s eta 0:00:13
#    ------------------------ --------------- 16.9/28.1 MB 880.0 kB/s eta 0:00:13
#    ------------------------ --------------- 17.0/28.1 MB 877.6 kB/s eta 0:00:13
#    ------------------------ --------------- 17.0/28.1 MB 877.6 kB/s eta 0:00:13
#    ------------------------ --------------- 17.0/28.1 MB 880.0 kB/s eta 0:00:13
#    ------------------------ --------------- 17.1/28.1 MB 878.8 kB/s eta 0:00:13
#    ------------------------ --------------- 17.1/28.1 MB 878.8 kB/s eta 0:00:13
#    ------------------------ --------------- 17.2/28.1 MB 878.8 kB/s eta 0:00:13
#    ------------------------ --------------- 17.2/28.1 MB 878.8 kB/s eta 0:00:13
#    ------------------------ --------------- 17.3/28.1 MB 877.6 kB/s eta 0:00:13
#    ------------------------ --------------- 17.3/28.1 MB 880.0 kB/s eta 0:00:13
#    ------------------------ --------------- 17.3/28.1 MB 880.0 kB/s eta 0:00:13
#    ------------------------ --------------- 17.4/28.1 MB 880.0 kB/s eta 0:00:13
#    ------------------------ --------------- 17.4/28.1 MB 880.0 kB/s eta 0:00:13
#    ------------------------ --------------- 17.4/28.1 MB 878.8 kB/s eta 0:00:13
#    ------------------------ --------------- 17.5/28.1 MB 878.8 kB/s eta 0:00:13
#    ------------------------ --------------- 17.6/28.1 MB 881.1 kB/s eta 0:00:12
#    ------------------------- -------------- 17.6/28.1 MB 877.6 kB/s eta 0:00:12
#    ------------------------- -------------- 17.6/28.1 MB 880.0 kB/s eta 0:00:12
#    ------------------------- -------------- 17.7/28.1 MB 880.0 kB/s eta 0:00:12
#    ------------------------- -------------- 17.7/28.1 MB 881.1 kB/s eta 0:00:12
#    ------------------------- -------------- 17.7/28.1 MB 877.6 kB/s eta 0:00:12
#    ------------------------- -------------- 17.8/28.1 MB 881.1 kB/s eta 0:00:12
#    ------------------------- -------------- 17.8/28.1 MB 881.2 kB/s eta 0:00:12
#    ------------------------- -------------- 17.9/28.1 MB 880.0 kB/s eta 0:00:12
#    ------------------------- -------------- 17.9/28.1 MB 880.0 kB/s eta 0:00:12
#    ------------------------- -------------- 18.0/28.1 MB 881.1 kB/s eta 0:00:12
#    ------------------------- -------------- 18.0/28.1 MB 878.8 kB/s eta 0:00:12
#    ------------------------- -------------- 18.0/28.1 MB 880.0 kB/s eta 0:00:12
#    ------------------------- -------------- 18.1/28.1 MB 878.8 kB/s eta 0:00:12
#    ------------------------- -------------- 18.1/28.1 MB 880.0 kB/s eta 0:00:12
#    ------------------------- -------------- 18.2/28.1 MB 877.6 kB/s eta 0:00:12
#    ------------------------- -------------- 18.2/28.1 MB 880.0 kB/s eta 0:00:12
#    ------------------------- -------------- 18.3/28.1 MB 878.8 kB/s eta 0:00:12
#    ------------------------- -------------- 18.3/28.1 MB 878.8 kB/s eta 0:00:12
#    -------------------------- ------------- 18.3/28.1 MB 878.8 kB/s eta 0:00:12
#    -------------------------- ------------- 18.4/28.1 MB 878.8 kB/s eta 0:00:12
#    -------------------------- ------------- 18.4/28.1 MB 880.0 kB/s eta 0:00:12
#    -------------------------- ------------- 18.4/28.1 MB 880.0 kB/s eta 0:00:11
#    -------------------------- ------------- 18.5/28.1 MB 880.0 kB/s eta 0:00:11
#    -------------------------- ------------- 18.5/28.1 MB 877.6 kB/s eta 0:00:11
#    -------------------------- ------------- 18.6/28.1 MB 878.8 kB/s eta 0:00:11
#    -------------------------- ------------- 18.6/28.1 MB 880.0 kB/s eta 0:00:11
#    -------------------------- ------------- 18.6/28.1 MB 880.0 kB/s eta 0:00:11
#    -------------------------- ------------- 18.7/28.1 MB 880.0 kB/s eta 0:00:11
#    -------------------------- ------------- 18.7/28.1 MB 877.6 kB/s eta 0:00:11
#    -------------------------- ------------- 18.8/28.1 MB 877.6 kB/s eta 0:00:11
#    -------------------------- ------------- 18.8/28.1 MB 878.8 kB/s eta 0:00:11
#    -------------------------- ------------- 18.9/28.1 MB 880.0 kB/s eta 0:00:11
#    -------------------------- ------------- 18.9/28.1 MB 878.8 kB/s eta 0:00:11
#    -------------------------- ------------- 19.0/28.1 MB 878.8 kB/s eta 0:00:11
#    --------------------------- ------------ 19.0/28.1 MB 880.0 kB/s eta 0:00:11
#    --------------------------- ------------ 19.0/28.1 MB 877.6 kB/s eta 0:00:11
#    --------------------------- ------------ 19.1/28.1 MB 880.0 kB/s eta 0:00:11
#    --------------------------- ------------ 19.1/28.1 MB 880.0 kB/s eta 0:00:11
#    --------------------------- ------------ 19.1/28.1 MB 878.8 kB/s eta 0:00:11
#    --------------------------- ------------ 19.2/28.1 MB 880.0 kB/s eta 0:00:11
#    --------------------------- ------------ 19.3/28.1 MB 880.0 kB/s eta 0:00:11
#    --------------------------- ------------ 19.3/28.1 MB 877.6 kB/s eta 0:00:11
#    --------------------------- ------------ 19.3/28.1 MB 878.8 kB/s eta 0:00:11
#    --------------------------- ------------ 19.4/28.1 MB 880.0 kB/s eta 0:00:10
#    --------------------------- ------------ 19.4/28.1 MB 878.8 kB/s eta 0:00:10
#    --------------------------- ------------ 19.4/28.1 MB 880.0 kB/s eta 0:00:10
#    --------------------------- ------------ 19.5/28.1 MB 875.2 kB/s eta 0:00:10
#    --------------------------- ------------ 19.5/28.1 MB 880.0 kB/s eta 0:00:10
#    --------------------------- ------------ 19.6/28.1 MB 880.0 kB/s eta 0:00:10
#    --------------------------- ------------ 19.6/28.1 MB 877.6 kB/s eta 0:00:10
#    --------------------------- ------------ 19.6/28.1 MB 878.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 19.7/28.1 MB 880.0 kB/s eta 0:00:10
#    ---------------------------- ----------- 19.7/28.1 MB 877.6 kB/s eta 0:00:10
#    ---------------------------- ----------- 19.8/28.1 MB 878.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 19.8/28.1 MB 878.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 19.8/28.1 MB 878.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 19.9/28.1 MB 877.6 kB/s eta 0:00:10
#    ---------------------------- ----------- 19.9/28.1 MB 881.1 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.0/28.1 MB 877.6 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.0/28.1 MB 878.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.1/28.1 MB 880.0 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.1/28.1 MB 878.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.2/28.1 MB 878.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.2/28.1 MB 880.0 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.2/28.1 MB 877.6 kB/s eta 0:00:09
#    ---------------------------- ----------- 20.3/28.1 MB 878.8 kB/s eta 0:00:09
#    ---------------------------- ----------- 20.3/28.1 MB 880.0 kB/s eta 0:00:09
#    ---------------------------- ----------- 20.3/28.1 MB 878.8 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.4/28.1 MB 878.8 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.4/28.1 MB 877.6 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.5/28.1 MB 877.6 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.5/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.6/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.6/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.6/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.7/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.7/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.8/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.8/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.8/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.9/28.1 MB 881.1 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.9/28.1 MB 881.2 kB/s eta 0:00:09
#    ----------------------------- ---------- 21.0/28.1 MB 878.8 kB/s eta 0:00:09
#    ----------------------------- ---------- 21.0/28.1 MB 880.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 21.1/28.1 MB 881.2 kB/s eta 0:00:09
#    ------------------------------ --------- 21.1/28.1 MB 878.8 kB/s eta 0:00:08
#    ------------------------------ --------- 21.1/28.1 MB 878.8 kB/s eta 0:00:08
#    ------------------------------ --------- 21.2/28.1 MB 877.6 kB/s eta 0:00:08
#    ------------------------------ --------- 21.2/28.1 MB 877.6 kB/s eta 0:00:08
#    ------------------------------ --------- 21.3/28.1 MB 881.2 kB/s eta 0:00:08
#    ------------------------------ --------- 21.3/28.1 MB 880.0 kB/s eta 0:00:08
#    ------------------------------ --------- 21.3/28.1 MB 878.8 kB/s eta 0:00:08
#    ------------------------------ --------- 21.4/28.1 MB 881.2 kB/s eta 0:00:08
#    ------------------------------ --------- 21.4/28.1 MB 877.6 kB/s eta 0:00:08
#    ------------------------------ --------- 21.4/28.1 MB 880.0 kB/s eta 0:00:08
#    ------------------------------ --------- 21.5/28.1 MB 880.0 kB/s eta 0:00:08
#    ------------------------------ --------- 21.5/28.1 MB 878.8 kB/s eta 0:00:08
#    ------------------------------ --------- 21.6/28.1 MB 878.8 kB/s eta 0:00:08
#    ------------------------------ --------- 21.6/28.1 MB 880.0 kB/s eta 0:00:08
#    ------------------------------ --------- 21.7/28.1 MB 877.6 kB/s eta 0:00:08
#    ------------------------------ --------- 21.7/28.1 MB 881.2 kB/s eta 0:00:08
#    ------------------------------ --------- 21.7/28.1 MB 880.0 kB/s eta 0:00:08
#    ------------------------------ --------- 21.8/28.1 MB 878.8 kB/s eta 0:00:08
#    ------------------------------- -------- 21.8/28.1 MB 880.0 kB/s eta 0:00:08
#    ------------------------------- -------- 21.9/28.1 MB 880.0 kB/s eta 0:00:08
#    ------------------------------- -------- 21.9/28.1 MB 877.6 kB/s eta 0:00:08
#    ------------------------------- -------- 22.0/28.1 MB 881.1 kB/s eta 0:00:07
#    ------------------------------- -------- 22.0/28.1 MB 880.0 kB/s eta 0:00:07
#    ------------------------------- -------- 22.0/28.1 MB 878.8 kB/s eta 0:00:07
#    ------------------------------- -------- 22.1/28.1 MB 880.0 kB/s eta 0:00:07
#    ------------------------------- -------- 22.1/28.1 MB 880.0 kB/s eta 0:00:07
#    ------------------------------- -------- 22.1/28.1 MB 880.0 kB/s eta 0:00:07
#    ------------------------------- -------- 22.2/28.1 MB 882.3 kB/s eta 0:00:07
#    ------------------------------- -------- 22.2/28.1 MB 876.4 kB/s eta 0:00:07
#    ------------------------------- -------- 22.2/28.1 MB 880.0 kB/s eta 0:00:07
#    ------------------------------- -------- 22.3/28.1 MB 880.0 kB/s eta 0:00:07
#    ------------------------------- -------- 22.3/28.1 MB 877.6 kB/s eta 0:00:07
#    ------------------------------- -------- 22.4/28.1 MB 878.8 kB/s eta 0:00:07
#    ------------------------------- -------- 22.5/28.1 MB 880.0 kB/s eta 0:00:07
#    ------------------------------- -------- 22.5/28.1 MB 877.6 kB/s eta 0:00:07
#    -------------------------------- ------- 22.5/28.1 MB 878.8 kB/s eta 0:00:07
#    -------------------------------- ------- 22.6/28.1 MB 880.0 kB/s eta 0:00:07
#    -------------------------------- ------- 22.6/28.1 MB 877.6 kB/s eta 0:00:07
#    -------------------------------- ------- 22.7/28.1 MB 878.8 kB/s eta 0:00:07
#    -------------------------------- ------- 22.7/28.1 MB 878.8 kB/s eta 0:00:07
#    -------------------------------- ------- 22.7/28.1 MB 878.8 kB/s eta 0:00:07
#    -------------------------------- ------- 22.8/28.1 MB 880.0 kB/s eta 0:00:07
#    -------------------------------- ------- 22.8/28.1 MB 878.8 kB/s eta 0:00:07
#    -------------------------------- ------- 22.9/28.1 MB 877.6 kB/s eta 0:00:06
#    -------------------------------- ------- 22.9/28.1 MB 877.6 kB/s eta 0:00:06
#    -------------------------------- ------- 22.9/28.1 MB 880.0 kB/s eta 0:00:06
#    -------------------------------- ------- 23.0/28.1 MB 878.8 kB/s eta 0:00:06
#    -------------------------------- ------- 23.0/28.1 MB 880.0 kB/s eta 0:00:06
#    -------------------------------- ------- 23.1/28.1 MB 877.6 kB/s eta 0:00:06
#    -------------------------------- ------- 23.1/28.1 MB 880.0 kB/s eta 0:00:06
#    -------------------------------- ------- 23.1/28.1 MB 878.8 kB/s eta 0:00:06
#    -------------------------------- ------- 23.2/28.1 MB 878.8 kB/s eta 0:00:06
#    --------------------------------- ------ 23.2/28.1 MB 880.0 kB/s eta 0:00:06
#    --------------------------------- ------ 23.3/28.1 MB 877.6 kB/s eta 0:00:06
#    --------------------------------- ------ 23.3/28.1 MB 876.5 kB/s eta 0:00:06
#    --------------------------------- ------ 23.3/28.1 MB 876.4 kB/s eta 0:00:06
#    --------------------------------- ------ 23.4/28.1 MB 878.8 kB/s eta 0:00:06
#    --------------------------------- ------ 23.4/28.1 MB 878.8 kB/s eta 0:00:06
#    --------------------------------- ------ 23.5/28.1 MB 877.6 kB/s eta 0:00:06
#    --------------------------------- ------ 23.5/28.1 MB 878.8 kB/s eta 0:00:06
#    --------------------------------- ------ 23.5/28.1 MB 877.6 kB/s eta 0:00:06
#    --------------------------------- ------ 23.6/28.1 MB 878.8 kB/s eta 0:00:06
#    --------------------------------- ------ 23.6/28.1 MB 878.8 kB/s eta 0:00:06
#    --------------------------------- ------ 23.7/28.1 MB 876.4 kB/s eta 0:00:06
#    --------------------------------- ------ 23.7/28.1 MB 878.8 kB/s eta 0:00:05
#    --------------------------------- ------ 23.7/28.1 MB 878.8 kB/s eta 0:00:05
#    --------------------------------- ------ 23.8/28.1 MB 876.4 kB/s eta 0:00:05
#    --------------------------------- ------ 23.8/28.1 MB 880.0 kB/s eta 0:00:05
#    --------------------------------- ------ 23.9/28.1 MB 877.6 kB/s eta 0:00:05
#    ---------------------------------- ----- 23.9/28.1 MB 877.6 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.0/28.1 MB 877.6 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.0/28.1 MB 880.0 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.0/28.1 MB 876.4 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.1/28.1 MB 878.8 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.1/28.1 MB 876.4 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.2/28.1 MB 877.6 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.2/28.1 MB 878.8 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.2/28.1 MB 878.8 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.3/28.1 MB 877.6 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.3/28.1 MB 880.0 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.4/28.1 MB 875.3 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.4/28.1 MB 878.8 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.4/28.1 MB 880.0 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.5/28.1 MB 877.6 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.5/28.1 MB 878.8 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.6/28.1 MB 881.2 kB/s eta 0:00:05
#    ----------------------------------- ---- 24.6/28.1 MB 876.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 24.7/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 24.7/28.1 MB 878.8 kB/s eta 0:00:04
#    ----------------------------------- ---- 24.7/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 24.8/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 24.8/28.1 MB 880.0 kB/s eta 0:00:04
#    ----------------------------------- ---- 24.9/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 24.9/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 24.9/28.1 MB 875.3 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.0/28.1 MB 881.2 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.0/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.0/28.1 MB 878.8 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.1/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.1/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.2/28.1 MB 880.0 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.2/28.1 MB 877.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.3/28.1 MB 878.8 kB/s eta 0:00:04
#    ------------------------------------ --- 25.3/28.1 MB 878.8 kB/s eta 0:00:04
#    ------------------------------------ --- 25.4/28.1 MB 877.6 kB/s eta 0:00:04
#    ------------------------------------ --- 25.4/28.1 MB 877.6 kB/s eta 0:00:04
#    ------------------------------------ --- 25.4/28.1 MB 878.8 kB/s eta 0:00:04
#    ------------------------------------ --- 25.5/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------ --- 25.5/28.1 MB 880.0 kB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 880.0 kB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 876.4 kB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 878.8 kB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 878.8 kB/s eta 0:00:03
#    ------------------------------------ --- 25.8/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------ --- 25.8/28.1 MB 880.0 kB/s eta 0:00:03
#    ------------------------------------ --- 25.9/28.1 MB 878.8 kB/s eta 0:00:03
#    ------------------------------------ --- 25.9/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------ --- 25.9/28.1 MB 880.0 kB/s eta 0:00:03
#    ------------------------------------ --- 26.0/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------- -- 26.0/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------- -- 26.0/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------- -- 26.1/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------- -- 26.1/28.1 MB 878.8 kB/s eta 0:00:03
#    ------------------------------------- -- 26.2/28.1 MB 881.1 kB/s eta 0:00:03
#    ------------------------------------- -- 26.2/28.1 MB 877.6 kB/s eta 0:00:03
#    ------------------------------------- -- 26.2/28.1 MB 880.0 kB/s eta 0:00:03
#    ------------------------------------- -- 26.3/28.1 MB 878.8 kB/s eta 0:00:03
#    ------------------------------------- -- 26.3/28.1 MB 880.0 kB/s eta 0:00:02
#    ------------------------------------- -- 26.4/28.1 MB 881.2 kB/s eta 0:00:02
#    ------------------------------------- -- 26.4/28.1 MB 878.8 kB/s eta 0:00:02
#    ------------------------------------- -- 26.5/28.1 MB 876.5 kB/s eta 0:00:02
#    ------------------------------------- -- 26.5/28.1 MB 880.0 kB/s eta 0:00:02
#    ------------------------------------- -- 26.6/28.1 MB 876.4 kB/s eta 0:00:02
#    ------------------------------------- -- 26.6/28.1 MB 878.8 kB/s eta 0:00:02
#    ------------------------------------- -- 26.6/28.1 MB 880.0 kB/s eta 0:00:02
#    ------------------------------------- -- 26.7/28.1 MB 878.8 kB/s eta 0:00:02
#    -------------------------------------- - 26.7/28.1 MB 876.4 kB/s eta 0:00:02
#    -------------------------------------- - 26.8/28.1 MB 880.0 kB/s eta 0:00:02
#    -------------------------------------- - 26.8/28.1 MB 877.6 kB/s eta 0:00:02
#    -------------------------------------- - 26.8/28.1 MB 878.8 kB/s eta 0:00:02
#    -------------------------------------- - 26.9/28.1 MB 881.2 kB/s eta 0:00:02
#    -------------------------------------- - 26.9/28.1 MB 877.6 kB/s eta 0:00:02
#    -------------------------------------- - 27.0/28.1 MB 880.0 kB/s eta 0:00:02
#    -------------------------------------- - 27.0/28.1 MB 880.0 kB/s eta 0:00:02
#    -------------------------------------- - 27.0/28.1 MB 877.6 kB/s eta 0:00:02
#    -------------------------------------- - 27.1/28.1 MB 880.0 kB/s eta 0:00:02
#    -------------------------------------- - 27.1/28.1 MB 877.6 kB/s eta 0:00:02
#    -------------------------------------- - 27.2/28.1 MB 876.4 kB/s eta 0:00:02
#    -------------------------------------- - 27.2/28.1 MB 880.0 kB/s eta 0:00:02
#    -------------------------------------- - 27.2/28.1 MB 880.0 kB/s eta 0:00:01
#    -------------------------------------- - 27.3/28.1 MB 882.3 kB/s eta 0:00:01
#    -------------------------------------- - 27.3/28.1 MB 882.3 kB/s eta 0:00:01
#    -------------------------------------- - 27.4/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.4/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.5/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.5/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.5/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.6/28.1 MB 880.0 kB/s eta 0:00:01
#    ---------------------------------------  27.6/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.7/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.7/28.1 MB 878.8 kB/s eta 0:00:01
#    ---------------------------------------  27.7/28.1 MB 876.4 kB/s eta 0:00:01
#    ---------------------------------------  27.8/28.1 MB 881.1 kB/s eta 0:00:01
#    ---------------------------------------  27.8/28.1 MB 878.8 kB/s eta 0:00:01
#    ---------------------------------------  27.9/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.9/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  27.9/28.1 MB 881.2 kB/s eta 0:00:01
#    ---------------------------------------  27.9/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  28.0/28.1 MB 880.0 kB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 880.0 kB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 877.6 kB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 861.3 kB/s eta 0:00:00
# Installing collected packages: llvmlite, numba, stumpy
# Successfully installed llvmlite-0.43.0 numba-0.60.0 stumpy-1.11.1
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import stumpy
from stumpy import core, config
from stumpy.scrump import _prescrump

# %% [markdown]
# Как мы помним из лекций:
#
# **Диапазонный диссонанс** – подпоследовательность ряда, расстояние от которой до ее ближайшего соседа не ниже заданного порога.
#
# Основными параметрами при поисках диссонансов являются:
# - $m$ - длина диссонанса
# - $r$ - пороговое значение расстояния подпоследовательности ряда, до его ближайшего соседа

# %%
from modules.drag import find_candidates, DRAG

# %% [markdown]
# Для поиска диссонансов в данной части практической работы мы воспользуемся алгоритмом **DRAG (Discord Range Aware Gathering)**.
# Для начала воспользуемся данным алгоритмом, чтобы найти диссонансы в наборе данных содержащем активность человека.

# %%
data = walk_run

# %% [markdown]
# Длину искомого диссонанса, как и для предыдущих алгоритмов, мы установим равно 50 точек.
# Пороговое значение мы установим равным большим, чтобы узнать, как алгоритм отреагирует на большие значения данного параметра.

# %%
m = 50 
r = 10
idxs, _, _ = DRAG(data,m,r)
print(f'Колличество найденных диссонансов: {len(idxs)}')
# Out:
# Колличество найденных диссонансов: 0

# %% [markdown]
# Как вы можете видеть мы установили слишком большое пороговое значение, алгоритму не удалось выделить ни одного диссонанса. Попробуем уменьшить пороговое значение до 1, чтобы улучшить результат.

# %%
m = 50 
r = 1
idxs, _, _ = DRAG(data, m, r)
print(f'Колличество найденных диссонансов: {len(idxs)}')
# Out:
# Колличество найденных диссонансов: 50

# %% [markdown]
# При такой комбинации параметров, улучшить ситуацию не получилось. Алгоритм выделил слишком большое количество диссонансов, часть которых является ложными диссонансами и не будут информативными для нас.

# %% [markdown]
# Произведите подобные эксперименты с набором данных такси NY. Постройте графики демонстрирующие найденные диссонансы. Пример Графика:
# ![second-graph](pics/fig_ex_2.png)

# %%
# INSERT YOUR CODE

# %% [markdown]
# Чтобы разобраться, почему так происходит и как работает данный алгоритм, ниже мы реализуем все этапы алгоритма DRAG.
#
# Как мы помним из лекций алгоритм DRAG содержит два этапа:
#
# 1. Отбор - За одно сканирование ряда сформировать множество кандидатов в диссонансы.
# 2. Очистка - За одно сканирование ряда отбросить кандидатов, которые являются ложными диссонансами.

# %% [markdown]
# ##### 3.2.1 Отбор кандидатов
#
# Первым этапом обработки данных является отбор множества потенциальных кандидатов. Мы выбираем из всего множества подпоследовательностей ряда такие, для которых расстояние до правых ближайших соседей больше параметра $r$.

# %%
#выбирем более реальное значение для порога
r = 3

# %%
T, M_T, Σ_T = core.preprocess(data, m)
#формируем массив длинной равной длине  исходного ряда - m + 1, 
#элемент массива является истинным, 
#в том случае если подпоследовательность является потенциальным кандидатом
is_cands = find_candidates(T, m, M_T, Σ_T, r, init_cands=None, right=True)
#находим индексы потенциальных кандидатов
cand_index = np.flatnonzero(is_cands)

# %%
print(f'{len(cand_index)} {len(cand_index)/len(data)*100} %')
# Out:
# 113 11.3 %

# %% [markdown]
# Во время отбора кандидатов нам удалось выделить около 113 подпоследовательностей(около 11.3%), которые мы бы могли назвать потенциальными диссонансами.
# Это большой процент, который не может нас устраивать как конечный результат.
# Если посмотреть на рисунок ниже, мы увидим, что большая часть потенциальных диссонансов расположена в районе смены активности.
# К сожалению пресутсвуют и ложные диссонансы, которые случайным образом попали в данный список.

# %% [markdown]
# Сформируйте график найденных диссонансов

# %%
# INSERT YOUR CODE

# %% [markdown]
# ##### 3.2.2 Очистка кандидатов
# Как уже упоминалось выше, 11.3% слишком большой процент диссонансов.
# Для уменьшения числа потенциальных кандидатов произведем очистку от ложных диссонансов, путем сравнения расстояния до левых ближайших соседей потенциальных диссонансов с порогом $r$.

# %%
is_cands = find_candidates(T, m, M_T, Σ_T, r, init_cands=is_cands, right=False)
cands = np.flatnonzero(is_cands)

# %%
len(cands)/len(data)*100
# Out:
# 2.9000000000000004

# %% [markdown]
# Сформируйте график найденных диссонансов

# %%
# INSERT YOUR CODE

# %% [markdown]
# Нам удалось сократить число диссонансов до 2.9%. Если проанализировать рисунок, то можно заметить, что большая их часть является тривиальными повторениями подпоследовательности в области смены активности. На следующем шаге избавимся от них.

# %%
from modules.drag import refine_candidates
discords_idx, discords_dist, discords_nn_idx = refine_candidates(T, m, M_T, Σ_T, is_cands)
len(discords_idx)/len(data)*100
# Out:
# 0.8999999999999999

# %% [markdown]
# Сформируйте график найденных диссонансов

# %%
# INSERT YOUR CODE

# %% [markdown]
# ##### 3.2.3 Подбор параметров

# %% [markdown]
# Реализуйте перебор параметров $m$ и $r$. Подберете параметры таким образом, чтобы алгоритм обнаружил только те диссонансы, которые связаны со сменой активности. Сделайте вывод о том, как эти параметры влияют на качество работы модели.
# Подберите оптимальные параметры алгоритма для набора данных такси NY.
# Визуализируйте результаты для разных комбинаций. Сделайте выводы.

# %%
# INSERT YOUR CODE

# %% [markdown]
# #### **3.3 Поиск диссонансов с помощью алгоритма Merlin**

# %% [markdown]
# Как мы уже выяснили подбирать параметры для DRAG простым перебором не очень удобно. Для оптимизации данного процесса в статье [1] был предложен алгоритм Merlin для оптимального поиска подходящего порогового значения.
#
# Условно мы можем разделить поиск диссонансов на три шага:
#
# 1. Поиск диссонансов минимальной длинны $minL$. На данном шаге $r = 2\sqrt{minL}$.
# 2. Поиск диссонансов следующих четырех длин. На данном шаге $r = 0.99 \cdot nndist_{m-1}$. Где $nndist_{m-1}$ - расстояние до ближайшего соседа предыдущего найденного диссонанса.
# 3. Поиск диссонансов всех
# оставшихся дли. $r = \mu - 2 \sigma$. Средние значение и стандартное отклонение вычисляются из расстояний 5 предыдущих диссонансов. н
#
# [1] Nakamura T., Imamura M., Mercer R., Keogh E.J. MERLIN: parameter-free discovery of arbitrary length anomalies in massive time series archives. 20th IEEE Int. Conf. on Data Mining, ICDM 2020, Sorrento, Italy, November 17-20, 2020. pp. 1190-1195. IEEE (2020). https://doi.org/10.1109/ICDM50108.2020.00147

# %% [markdown]
# ##### 3.3.1 Поиск диссонансов минимальной длинны

# %% [markdown]
# Вспомнил последовательность действий первого шага алгоритма:
# ![merlin-part-first](pics/first_part.png)
#
# В данной работе мы внесем небольшое изменение, мы будем считать, что подпоследовательность может быть диссонансом только в том случае, если больше 75% точек, не входят в состав других диссонансов.

# %%
T = walk_run
m = 50
# сформируем массив метод для потенциальных кандидатов в диссонансы.
# после каждого найденного диссонанса, 
# мы будем исключать окружающие его подпоследовательности из числа потенциальных кандидатов,
# путем замены значений их меток на false
excl_zone = int(np.ceil(m / 4))
include = np.ones(len(T)-m+1, dtype=bool)
# Количество диссонансов, которые мы будем искать
topK = 10

# %%
dis_idx = -np.ones((topK))
dis_nnDist = -np.ones((topK))
dis_nn_idx = np.full((topK),-np.inf)
#первое прближение r
r = 2*np.sqrt(m)
minL = m
maxL = int(m+np.ceil(m*0.1))
#количество найденных диссонасов
cound_find_dis = 0

while dis_nnDist[cound_find_dis-1]<0 and cound_find_dis<topK:
    result = DRAG(data=T,m=minL,r=r, include =include)
    for diss, nnDist, nn in zip(*result):
        dis_idx[cound_find_dis] = diss
        dis_nnDist[cound_find_dis] = nnDist
        dis_nn_idx[cound_find_dis] = nn
        #исключаем окружающие найденный диссонас 
        #подпоследовательности и числа потенциальных диссонасов
        core.apply_exclusion_zone(include, diss, excl_zone, False)
        cound_find_dis+=1
        if cound_find_dis>=topK:
            break
    r*=0.5

# %%
maxL
# Out:
# 55

# %%
print('Количество найденных на первом этапе диссонансов:', cound_find_dis)
# Out:
# Количество найденных на первом этапе диссонансов: 2

# %% [markdown]
# На первом шаге нам удалось выделить 2 диссонанса из 10 требуемых.
# Реализуйте, оставшиеся шаги алгоритма, чтобы найти оставшиеся диссонансы.
#
# ![merlin-part-first](pics/second_part.png)

# %%
# INSERT YOUR CODE

# %% [markdown]
# Найдите диссонансы набора такси NY. Визуализируйте найденные диссонансы для обоих наборов данных, сравните с результатами остальных методов.

# %%
# INSERT YOUR CODE
